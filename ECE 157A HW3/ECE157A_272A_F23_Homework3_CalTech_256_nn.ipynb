# %% [markdown]
# For this part of the homework, we will work with a subset of the CalTech-256 dataset, a widely recognized image dataset comprising a diverse collection of 256 object categories. This subset contains 10 specific classes from the CalTech-256 dataset. Your first task is to review the images in this dataset and compare how the classification task for this dataset differs from the other two datasets in this homework. You will then need to adjust and execute the code to observe how a Convolutional Neural Network (CNN) trained from scratch performs in comparison to a fine-tuned VGG16 model when applied to this specific dataset. Furthermore, you should evaluate and compare the performance of the two models on both the CalTech-256 dataset and the other dataset.
#
# For the coding task, your main objectives are as follows:
#
# + Modify the data preprocessing functions, dataset class, and data loaders to be compatible with the CalTech-256 dataset. Please be aware that, unlike the HAM10000 dataset, the CalTech-256 dataset contains images of varying sizes.
#
# + Modify the existing model architecture and the VGG16 model to work with this dataset.

# %% [markdown]
# # Download Dataset
# + Download dataset from Box
# + (You can download the images to your desktop by using the link https://ucsb.box.com/shared/static/vz9pmd1h7eexf2qxr5odvjy0xew5aqpo.zip)
# + unzip dataset

# %%
# !wget -nc -O dataset.zip https://ucsb.box.com/shared/static/vz9pmd1h7eexf2qxr5odvjy0xew5aqpo.zip
# Out:
# --2023-11-16 21:26:33--  https://ucsb.box.com/shared/static/vz9pmd1h7eexf2qxr5odvjy0xew5aqpo.zip
# Resolving ucsb.box.com (ucsb.box.com)... 74.112.186.144
# Connecting to ucsb.box.com (ucsb.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/vz9pmd1h7eexf2qxr5odvjy0xew5aqpo.zip [following]
# --2023-11-16 21:26:33--  https://ucsb.box.com/public/static/vz9pmd1h7eexf2qxr5odvjy0xew5aqpo.zip
# Reusing existing connection to ucsb.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ucsb.app.box.com/public/static/vz9pmd1h7eexf2qxr5odvjy0xew5aqpo.zip [following]
# --2023-11-16 21:26:33--  https://ucsb.app.box.com/public/static/vz9pmd1h7eexf2qxr5odvjy0xew5aqpo.zip
# Resolving ucsb.app.box.com (ucsb.app.box.com)... 74.112.186.144
# Connecting to ucsb.app.box.com (ucsb.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!bc337tk93RHH-4xHk5RSsqwvmnNOg4w138fA41_Hlk8Rw_y80UBAkWZbQ8Tdf3Dp6za3H5BVzdTW33l0SferFJ1eDW4uVo3CyY86wnjtzY-w8zbLnA5BSniIp9Lb1d27Joq8CP4lERiDv8hQXr7ZQOmzzELzQP4ezEYrCEo2v7CCIxt6N1lvNSMPe8UMA_t_Kdti31R667zexmuYh8TqUnuP-mQHlidT-xr09m88ENDUnJX0SYymBL9m5b-sl0ls9LElpBSgH_TjNaZG7_Vi_LFCTN9pQR8RoryUmjy7dhxkwI1ULnkrOqntKfQZ8PiDyHKZNeRKlP9GyAUbjNhwaR5wreWHsWs28hhUohW_2_ropiCFSS5fkGjX-RyFJ6BpZ8qrEbRoYJqu65Zp-3P-KHeifOpikfnZMP-AYj3ilFTaU25PC-sK0oVdl8zex3nTPhwRTi8TVR3mbzxZvZFdJrdxRulx3P_KoJcoLcFXpM9Lh2uwuKKcAeSDa59lAbYOrHy2JGrn9tGz5S0kwg7622vXV7LkSKS21hxARC7f18hYb7RLJrPAR38ju9grWstynoPU6O5ci5JyPaL0c1iS-bQmsIsWmDnaNh7bH4z-M853IOLKOAew_s0SiZFXYXBhDJyzT_353jZv5xLOBHap__uB2prlAncy8iM1s1MevYI3rgaIjy2XRIa0pFf5JykD2I9zLKNrTM8LAQj6owEMMed8d19AmYKL-QZJ7G43FYXCv5KKN0TTXJyTba4dSuyl3j-DG6A8hz06lrVle9AVQonwRD5O4_-JXSdWLHhnJ3W2D8uZVt2z4U7YjNotuIr3QdQQ2GuUSATY5bBBFFSnkClFDdd-1wFF6iTuN8RsTBI5afBzrSAMruETPC1BdXqldfMzkjDpSQxmI7-POlDrFA1INo3Z_QENHumx-c4bBHeOpA1q_eT4Yk_CTkw4DizCVqYnWFvUFZVG_hHT7HCLes2_mML8sQdn2vtUTqI43u34AjDVlwAm6ETPBeNJpJyQwGqMkTDWXdCl7BM_9SQlp6bY5k19xVRr0Aed3mdlUUm967Ex3T7fsdZEBA5PkfmN8VmH8pT_nVGm2Z6zAzn0YI_3YOOpulLR8WbafhdisbtinAA1s5YlaOs8D28z-Chq6EV1HBMlw7gDXae6rnbNQuy70flT-76nuxELfT_EEZADfszvsNrjUxnUw_9cjc_rkVykJyuxPjbMD0YKT0CqMsjkin7vfOV7WXDPL4urXCvlqrGIKed-DwIiEr-0VvkGyBQ0DAJSaRnEdJHE9-xNC0gJTuLjexXLZbfaxmThcJxRD5aRluK0J0C1N0mwuq_EQ_FFUk-ie4Ix13QXxc4L40BIYmsiR1aTxXNGpnvSckn4tw../download [following]
# --2023-11-16 21:26:34--  https://public.boxcloud.com/d/1/b1!bc337tk93RHH-4xHk5RSsqwvmnNOg4w138fA41_Hlk8Rw_y80UBAkWZbQ8Tdf3Dp6za3H5BVzdTW33l0SferFJ1eDW4uVo3CyY86wnjtzY-w8zbLnA5BSniIp9Lb1d27Joq8CP4lERiDv8hQXr7ZQOmzzELzQP4ezEYrCEo2v7CCIxt6N1lvNSMPe8UMA_t_Kdti31R667zexmuYh8TqUnuP-mQHlidT-xr09m88ENDUnJX0SYymBL9m5b-sl0ls9LElpBSgH_TjNaZG7_Vi_LFCTN9pQR8RoryUmjy7dhxkwI1ULnkrOqntKfQZ8PiDyHKZNeRKlP9GyAUbjNhwaR5wreWHsWs28hhUohW_2_ropiCFSS5fkGjX-RyFJ6BpZ8qrEbRoYJqu65Zp-3P-KHeifOpikfnZMP-AYj3ilFTaU25PC-sK0oVdl8zex3nTPhwRTi8TVR3mbzxZvZFdJrdxRulx3P_KoJcoLcFXpM9Lh2uwuKKcAeSDa59lAbYOrHy2JGrn9tGz5S0kwg7622vXV7LkSKS21hxARC7f18hYb7RLJrPAR38ju9grWstynoPU6O5ci5JyPaL0c1iS-bQmsIsWmDnaNh7bH4z-M853IOLKOAew_s0SiZFXYXBhDJyzT_353jZv5xLOBHap__uB2prlAncy8iM1s1MevYI3rgaIjy2XRIa0pFf5JykD2I9zLKNrTM8LAQj6owEMMed8d19AmYKL-QZJ7G43FYXCv5KKN0TTXJyTba4dSuyl3j-DG6A8hz06lrVle9AVQonwRD5O4_-JXSdWLHhnJ3W2D8uZVt2z4U7YjNotuIr3QdQQ2GuUSATY5bBBFFSnkClFDdd-1wFF6iTuN8RsTBI5afBzrSAMruETPC1BdXqldfMzkjDpSQxmI7-POlDrFA1INo3Z_QENHumx-c4bBHeOpA1q_eT4Yk_CTkw4DizCVqYnWFvUFZVG_hHT7HCLes2_mML8sQdn2vtUTqI43u34AjDVlwAm6ETPBeNJpJyQwGqMkTDWXdCl7BM_9SQlp6bY5k19xVRr0Aed3mdlUUm967Ex3T7fsdZEBA5PkfmN8VmH8pT_nVGm2Z6zAzn0YI_3YOOpulLR8WbafhdisbtinAA1s5YlaOs8D28z-Chq6EV1HBMlw7gDXae6rnbNQuy70flT-76nuxELfT_EEZADfszvsNrjUxnUw_9cjc_rkVykJyuxPjbMD0YKT0CqMsjkin7vfOV7WXDPL4urXCvlqrGIKed-DwIiEr-0VvkGyBQ0DAJSaRnEdJHE9-xNC0gJTuLjexXLZbfaxmThcJxRD5aRluK0J0C1N0mwuq_EQ_FFUk-ie4Ix13QXxc4L40BIYmsiR1aTxXNGpnvSckn4tw../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 74.112.186.128
# Connecting to public.boxcloud.com (public.boxcloud.com)|74.112.186.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 485260416 (463M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>] 462.78M  13.6MB/s    in 34s
#
# 2023-11-16 21:27:09 (13.7 MB/s) - ‘dataset.zip’ saved [485260416/485260416]

# %%
# !unzip -n dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034886.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034887.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034888.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034889.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034890.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034891.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034895.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034896.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034898.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034899.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034904.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034905.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034906.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034910.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034911.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034914.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034915.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034918.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034926.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034930.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034931.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034934.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034936.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034937.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034939.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034946.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034948.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034949.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034951.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034952.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034953.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034954.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034957.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034958.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034959.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034960.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034961.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034966.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034970.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034971.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034972.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034980.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034982.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034987.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034988.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034993.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034994.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034995.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034997.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034998.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0034999.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035000.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035001.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035004.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035008.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035010.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035012.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035018.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035021.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035026.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035028.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035029.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035032.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035033.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035035.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035037.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035039.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035040.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035041.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035042.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035043.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035047.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035048.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035054.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035057.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035064.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035070.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035072.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035075.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035076.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035078.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035081.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035089.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035090.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035095.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035099.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035104.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035106.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035109.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035110.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035112.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035115.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035117.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035119.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035120.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035124.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035125.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035127.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035128.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035130.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035131.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035136.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035139.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035142.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035147.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035149.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035151.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035154.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035155.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035163.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035168.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035171.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035177.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035179.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035180.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035185.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035190.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035194.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035196.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035202.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035206.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035207.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035210.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035212.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035216.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035218.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035224.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035226.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035229.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035232.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035239.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035240.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035243.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035247.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035248.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035254.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035258.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035259.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035261.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035262.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035263.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035264.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035270.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035271.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035276.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035277.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035280.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035284.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035287.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035291.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035293.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035305.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035306.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035308.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035310.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035313.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035316.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035317.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035318.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035321.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035322.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035326.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035330.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035331.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035332.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035334.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035338.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035340.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035345.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035348.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035351.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035355.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035357.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035360.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035362.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035364.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035366.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035368.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035372.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035374.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035376.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035388.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035389.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035391.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035393.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035397.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035403.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035406.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035414.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035415.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035416.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035420.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035421.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035430.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035432.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035434.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035436.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035439.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035440.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035443.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035446.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035450.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035451.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035454.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035459.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035460.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035462.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035463.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035464.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035466.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035468.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035471.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035472.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035475.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035478.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035486.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035487.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035490.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035504.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035505.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035510.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035511.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035517.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035522.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035525.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035533.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035538.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035547.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035550.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035552.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035553.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035556.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035558.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035561.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035562.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035564.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035570.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035584.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035585.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035586.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035588.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035589.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035590.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035593.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035594.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035599.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035602.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035603.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035605.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035606.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035607.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035608.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035610.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035612.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035613.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035619.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035622.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035624.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035625.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035626.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035627.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035629.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035630.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035631.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035633.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035634.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035635.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035636.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035637.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035640.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035642.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035643.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035645.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035650.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035651.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035653.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035655.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035658.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035660.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035661.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035663.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035664.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035667.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035669.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035670.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035675.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035676.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035677.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035679.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035680.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035682.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035683.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035685.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035690.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035691.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035692.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035694.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035695.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035696.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035698.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035700.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035701.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035705.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035708.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035711.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035714.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035715.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035718.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035719.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035720.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035721.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035723.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035724.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035729.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035730.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035732.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035733.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035735.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035736.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035737.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035739.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035741.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035744.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035747.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035748.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035750.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035751.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035752.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035753.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035754.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035755.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035756.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035759.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035761.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035763.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035764.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035765.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035766.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035767.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035768.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035772.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035776.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035778.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035787.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035789.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035790.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035794.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035799.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035802.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035805.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035807.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035810.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035814.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035816.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035818.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035819.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035821.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035823.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035824.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035825.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035826.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035827.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035829.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035831.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035833.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035834.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035842.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035844.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035845.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035846.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035847.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035848.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035852.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035853.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035854.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035855.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035863.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035865.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035866.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035868.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035871.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035873.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035876.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035877.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035878.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035881.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035882.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035887.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035888.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035889.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035890.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035894.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035899.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035900.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035901.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035902.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035904.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035905.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035908.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035910.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035911.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035913.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035914.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035915.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035917.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035918.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035919.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035920.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035922.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035923.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035925.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035926.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035929.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035931.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035932.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035933.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035934.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035937.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035938.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035940.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035942.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035944.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035946.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035949.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035950.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035952.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035953.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035955.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035956.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035957.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035959.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035960.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035964.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035968.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035976.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035977.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035982.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035986.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035992.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035993.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035996.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0035997.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036000.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036002.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036003.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036004.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036005.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036006.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036007.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036008.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036009.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036011.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036012.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036015.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036016.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036018.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036019.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036021.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036022.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036023.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036025.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036026.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036029.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036031.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036032.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036034.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036035.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036043.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036050.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036051.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036053.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036056.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036057.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036060.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036062.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036063.jpg
#   inflating: datasets/HAM10000/test/not_label/ISIC_0036064.jpg
#    creating: datasets/HAM10000/train/
#    creating: datasets/HAM10000/train/AKIEC/
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024329.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024372.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024418.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024450.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024463.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024468.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024470.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024511.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024517.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024522.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024539.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024562.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024575.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024579.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024646.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024654.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024707.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024710.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024763.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024771.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024800.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024843.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024913.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024923.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024925.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024946.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0024948.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025029.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025069.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025089.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025130.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025178.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025182.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025196.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025247.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025264.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025319.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025331.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025350.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025358.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025368.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025411.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025427.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025471.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025539.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025577.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025605.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025637.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025696.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025712.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025780.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025790.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025803.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025808.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025811.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025825.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025831.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025948.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025953.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025957.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0025992.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026014.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026040.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026083.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026100.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026132.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026138.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026149.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026152.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026171.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026178.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026194.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026203.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026206.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026212.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026319.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026327.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026362.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026388.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026411.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026457.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026466.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026468.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026492.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026522.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026525.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026549.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026575.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026625.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026626.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026645.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026650.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026702.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026709.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026720.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026729.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026765.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026848.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026857.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026872.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026905.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026927.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026981.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026984.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0026992.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027047.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027084.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027172.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027178.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027184.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027231.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027254.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027294.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027303.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027334.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027343.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027447.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027452.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027506.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027529.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027536.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027550.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027562.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027577.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027580.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027588.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027615.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027650.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027668.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027678.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027700.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027708.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027719.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027753.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027767.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027795.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027802.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027829.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027884.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027896.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027930.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027950.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0027958.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028063.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028076.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028132.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028158.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028190.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028224.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028231.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028232.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028314.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028335.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028370.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028372.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028381.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028393.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028499.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028517.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028558.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028619.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028644.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028659.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028730.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028763.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028795.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028816.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028820.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028854.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028872.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028941.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0028990.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029002.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029025.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029041.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029043.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029059.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029067.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029133.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029141.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029210.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029268.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029279.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029309.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029315.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029360.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029362.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029371.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029417.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029460.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029462.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029500.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029533.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029541.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029549.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029563.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029567.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029573.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029582.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029598.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029610.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029634.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029638.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029659.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029713.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029715.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029781.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029811.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029827.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029830.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029840.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029851.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029860.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029900.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029915.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029930.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0029932.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030036.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030076.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030133.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030142.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030143.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030158.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030175.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030191.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030242.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030245.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030280.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030297.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030341.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030344.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030375.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030387.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030408.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030463.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030487.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030491.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030549.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030586.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030591.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030602.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030655.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030707.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030714.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030730.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030785.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030794.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030803.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030821.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030825.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030826.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030827.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030844.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030877.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030953.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030986.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0030991.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031012.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031040.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031043.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031044.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031108.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031119.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031191.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031198.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031211.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031228.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031286.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031292.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031335.jpg
#   inflating: datasets/HAM10000/train/AKIEC/ISIC_0031381.jpg
# ...
#   inflating: datasets/HAM10000/train/NV/ISIC_0025892.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025893.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025894.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025895.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025896.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025897.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025898.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025899.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025900.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025901.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025902.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025905.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025907.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025908.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025909.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025910.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025912.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025913.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025914.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025916.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025917.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025918.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025919.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025920.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025921.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025922.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025923.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025925.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025926.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025929.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025930.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025931.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025933.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025934.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025935.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025936.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025938.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025942.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025943.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025944.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025945.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025946.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025947.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025949.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025950.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025951.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025952.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025956.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025958.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025959.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025960.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025961.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025962.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025965.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025966.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025967.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025968.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025969.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025970.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025972.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025974.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025976.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025977.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025978.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025979.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025981.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025983.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025988.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025989.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025990.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025991.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025993.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025994.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025995.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025997.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025998.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0025999.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026000.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026001.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026002.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026003.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026004.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026005.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026006.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026007.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026008.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026010.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026011.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026012.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026013.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026017.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026019.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026020.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026021.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026022.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026023.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026024.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026025.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026026.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026027.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026028.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026029.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026030.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026031.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026032.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026033.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026034.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026035.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026036.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026037.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026038.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026039.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026041.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026043.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026047.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026048.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026049.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026050.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026051.jpg
#   inflating: datasets/HAM10000/train/NV/ISIC_0026052.jpg
#    creating: datasets/HAM10000/train/VASC/
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024370.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024375.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024402.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024475.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024662.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024669.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024706.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024747.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024867.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0024904.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025197.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025244.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025249.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025250.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025321.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025425.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025452.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025578.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025596.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025599.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025606.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025612.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025628.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025677.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025680.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025707.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025807.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025873.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0025924.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026068.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026092.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026163.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026336.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026349.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026393.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026456.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026467.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026490.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026693.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026713.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0026876.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027159.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027210.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027256.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027269.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027385.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027522.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027563.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027665.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027672.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027790.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027856.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027888.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027903.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027937.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0027983.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0028146.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0028163.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0028188.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0028406.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0028431.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0028680.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0028714.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0028885.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029099.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029404.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029439.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029448.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029486.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029514.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029608.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029742.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029877.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0029889.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030070.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030104.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030275.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030283.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030606.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030722.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030770.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030882.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0030956.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031065.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031090.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031093.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031103.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031197.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031201.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031215.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031217.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031270.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031276.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031346.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031648.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031706.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031719.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031759.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031901.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031950.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031955.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0031996.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032057.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032076.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032240.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032270.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032409.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032538.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032545.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032557.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032614.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032692.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032715.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032745.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032775.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032839.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032866.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032867.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032890.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032919.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0032932.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033031.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033092.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033123.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033135.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033158.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033230.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033254.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033349.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033450.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033458.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033565.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033591.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033608.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033749.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033762.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033817.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033844.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033969.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0033991.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0034196.jpg
#   inflating: datasets/HAM10000/train/VASC/ISIC_0034214.jpg
#    creating: datasets/WM811K/
#    creating: datasets/WM811K/test/
#   inflating: datasets/WM811K/test/wafermap_test.npy
#    creating: datasets/WM811K/train/
#   inflating: datasets/WM811K/train/wafermap_train.npy

# %% [markdown]
# # Import libraries

# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
import torchvision
from torchvision.models import vgg16, VGG16_Weights
import numpy as np
import pandas as pd
from typing import Dict, Final, List, Tuple, NamedTuple, Type, Union
from tqdm.auto import tqdm, trange
import torch
from torchvision import transforms, datasets

import cv2

from collections import Counter

import skimage.transform

import matplotlib.pyplot as plt

from PIL import Image

TODO: Type = NotImplemented

print("PyTorch Version: ", torch.__version__)
print("Torchvision Version: ", torchvision.__version__)
# Out:
# PyTorch Version:  2.1.0+cu118
# Torchvision Version:  0.16.0+cu118

# %% [markdown]
# # Type Definition
# Define some types for clearer labeling of our interfaces.

# %%
TODO = NotImplemented  # NOTE: This is a placeholder for code that needs to be written

Loss: Type = float
Accuracy: Type = float


class LossAcc(NamedTuple):
    loss: Loss
    accuracy: Accuracy


class TrainValLossAcc(NamedTuple):
    train: List[List[LossAcc]]
    val: List[LossAcc]


example_result_pair: LossAcc = LossAcc(1.6, 0.7)
print("loss:", example_result_pair.loss)
print("accuracy:", example_result_pair.accuracy)
print(example_result_pair)
# Out:
# loss: 1.6
# accuracy: 0.7
# LossAcc(loss=1.6, accuracy=0.7)

# %% [markdown]
# # Configurations
# Some configuration options that are required to make the dataset work with PyTorch.

# %%
num_epochs: Final[int] = 20

batch_size: Final[int] = 16

valid_set_size: Final[float] = 0.30

print("Number of epochs: ", num_epochs)
print("Batch size: ", batch_size)
# Out:
# Number of epochs:  20
# Batch size:  16

# %% [markdown]
# # Loading CalTech-256 training data from directory
#
# 1. Define Data Transforms:
#
#   + Define data transformations using `transforms.Compose`. This should include
#     + Padding to make the image a square.
#     + Conversion to a tensor. Converts a PIL Image or numpy.ndarray (H x W x C) in the range `[0, 255]` to a torch.FloatTensor of shape (C x H x W) in the range `[0.0, 1.0]`.
#     + Resizing to (224, 224).
#     + Optionally, you can include other preprocessing steps.
#   + Padding is added to maintain the aspect ratio of the image content when resizing to (224, 224).
#
# 2. Load the CalTech-256 Dataset:
#
#   + Set the path to your CalTech-256 `train` dataset directory.
#   + Create the dataset using the `datasets.ImageFolder` class. This class automatically assigns labels based on the subdirectory names.
#
# 3. Get Class Labels:
#
#   + Obtain the class labels (class names) from the `all_dataset.classes` attribute. This will give you a list of class labels in the order they appear in the dataset.

# %%
# Define a custom data transform to pad the image to be square
class SquarePad(object):
    def __init__(self, fill_color=(0, 0, 0)):
        self.fill_color = fill_color

    def __call__(self, img):
        width, height = img.size

        # Calculate the size of the square canvas
        size = max(width, height)

        # Create a new blank image with the square size
        new_img = Image.new('RGB', (size, size), self.fill_color)

        # Paste the original image onto the center of the square canvas
        new_img.paste(img, ((size - width) // 2, (size - height) // 2))

        return new_img

# %%
# Define the data transformations composing of
# - Padding to make the image a square
# - Conversion to a tensor
# - Resize to size (224, 224)
# Compose: https://pytorch.org/vision/main/generated/torchvision.transforms.Compose.html
data_transforms = data_transforms = transforms.Compose([
    SquarePad(),
    transforms.ToTensor(),
    transforms.Resize((224, 224),antialias=True)
])  # CODE HERE

# Set the path to your CalTech-256 train dataset directory
data_dir =  '/content/datasets/CalTech-256/train' # CODE HERE

# Create a dataset using ImageFolder
# ImageFolder: https://pytorch.org/vision/main/generated/torchvision.datasets.ImageFolder.html
all_dataset =  datasets.ImageFolder(root=data_dir, transform=data_transforms) # CODE HERE

# get the classes attribute from all_dataset
classes: Final[List[str]] = all_dataset.classes  # CODE HERE

num_classes: Final[int] = len(classes)
print(f'Number of classes: {len(classes)}')
# Out:
# Number of classes: 10

# %% [markdown]
# PyTorch provides the `torch.utils.data.random_split()` function to split a dataset. This method takes a dataset and a list of lengths/ratios, and returns a list of datasets of the specified lengths/ratios. If lengths are given, the sum of the lengths must equal the length of the original dataset. If ratios are given, the sum of the ratios must equal to 1. In the configuration block above, we have already computed `test_set_sample_count` and `test_set_actual_size` for you, so you can use it to create a train/valid split.
#
# To get a consistent split, you are able to set your own random seed, though the process is more complex than for `scikit-learn`. To do so, add the argument `generator=torch.Generator().manual_seed(9)` to the `random_split()` function call. This split has produced a good class balance in our testing, but you are welcome to experiment with different `valid_set_size` and `manual_seed` values.

# %%
# random_split: https://pytorch.org/docs/stable/data.html#torch.utils.data.random_split
val_set_sample_count = int(len(all_dataset) * valid_set_size)
train_set_sample_count = len(all_dataset) - val_set_sample_count
train_dataset, val_dataset =  random_split(
    all_dataset,
    [train_set_sample_count, val_set_sample_count],
    generator=torch.Generator().manual_seed(9)
) # CODE HERE

# %% [markdown]
# Once arranged into a `Dataset`, we wrap the `Dataset` in a `Dataloader` object. This object is used to iterate over the dataset in batches, shuffle the dataset, and perform other useful operations, like parallel data loading.

# %%
# DataLoader: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#preparing-your-data-for-training-with-dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)  # CODE HERE
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)  # CODE HERE

# %% [markdown]
# The below visualization of class label balances is provided for your reference. The train/valid split should produce similar class label balances.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define a function to plot class label distribution as ratios
def plot_class_distribution_ratios(train_dataset, val_dataset):
    class_counts_train = [0] * len(train_dataset.dataset.classes)
    class_counts_val = [0] * len(val_dataset.dataset.classes)

    for _, label in train_dataset:
        class_counts_train[label] += 1

    for _, label in val_dataset:
        class_counts_val[label] += 1

    # Calculate the total number of samples in the entire dataset
    total_train_samples = sum(class_counts_train)
    total_valid_samples = sum(class_counts_val)

    # Calculate class ratios
    class_ratios_train = [count / total_train_samples for count in class_counts_train]
    class_ratios_val = [count / total_valid_samples for count in class_counts_val]

    class_labels = train_dataset.dataset.classes
    width = 0.35
    x = np.arange(len(class_labels))

    plt.figure(figsize=(9, 4))
    plt.bar(x - width/2, class_ratios_train, width, label='Training Set')
    plt.bar(x + width/2, class_ratios_val, width, label='Validation Set')
    plt.xlabel('Class Label')
    plt.ylabel('Class Ratio (to Total Samples)')
    plt.title('Class Ratios in Training and Validation Sets')
    plt.xticks(x, class_labels, rotation=45)
    plt.legend()
    plt.show()

# Plot class ratios for training and validation sets
plot_class_distribution_ratios(train_dataset, val_dataset)

# %% [markdown]
# # Custom Neural Network Model
#
# Now we'll define a new network. We'll use this network to train on the CalTech-256 dataset. We'll use the `torch.nn` module to define the network. This module provides a number of useful building blocks for neural networks, including linear layers, convolution layers, dropout layers, maxpooling layers, activation functions, flatten function, and loss functions.
#
# If this is your absolute first interaction with PyTorch, you may find [this basic tutorial link](https://pytorch.org/tutorials/beginner/basics/buildmodel_tutorial.html) and [this CNN tutorial link](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#define-a-convolutional-neural-network) to be of use.

# %%
import torch.nn as nn

class CalTechNetwork(nn.Module):
    def __init__(self, dropout_prob=0.5):
        super(CalTechNetwork, self).__init__()
        # Define the convolutional layers
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(128 * 14 * 14, 128)  # Adjust the input size based on your needs
        self.fc2 = nn.Linear(128, 10)
        self.dropout = nn.Dropout(p=dropout_prob)

    def forward(self, x):
        x = self.pool(nn.functional.relu(self.conv1(x)))
        x = self.dropout(x)  # Apply dropout after the first convolutional layer
        x = self.pool(nn.functional.relu(self.conv2(x)))
        x = self.dropout(x)  # Apply dropout after the second convolutional layer
        x = self.pool(nn.functional.relu(self.conv3(x)))
        x = self.dropout(x)  # Apply dropout after the third convolutional layer
        x = self.pool(nn.functional.relu(self.conv4(x)))
        x = self.dropout(x)  # Apply dropout after the fourth convolutional layer
        x = x.view(x.size(0), -1)  # Adjust the input size based on your needs
        x = nn.functional.relu(self.fc1(x))
        x = self.dropout(x)  # Apply dropout after the first fully connected layer
        x = self.fc2(x)
        return x

# Create an instance of the CalTechNetwork model with dropout
dropout_prob = 0.5  # You can adjust the dropout probability as needed
model = CalTechNetwork(dropout_prob)

# %% [markdown]
# # Validate Function
#
# We will define the `validate` function that evaluates the performance of the model after every training epoch. This function simply puts the network into `eval` mode, then iterates over the validation dataset and computes the accuracy and loss of the network.
#
# Accuracy computations you can perform in similar manner as you have in the past assignments. For loss computations, we will use the `torch.nn.functional.cross_entropy` function, which assumes the network outputs class logits, and computes the cross entropy loss between the logits and the ground truth labels.
#
# Some components of models behave differently whether they're under training or validation. For example, dropout layers will randomly drop out nodes during training, but will not do so during validation. To handle this, PyTorch provides the `.train()` method to set the model into training mode and the `.eval()` method to set the model into validation mode. We will use this to set the model into validation mode before computing the accuracy and loss.
#
# Running data through a model is as simple as treating the model as a function! That is, `model(data)` will run the data through the model and return the output. We can then use this output to compute the accuracy and loss.
#
# The result of `torch.tensor` computations is always more `torch.tensor`s, so use the `.item()` method to get the actual value of the loss and/or accuracy when you are ready to store it.
#
# To leverage a GPU for speeding up the computation, you should move the model, data, and labels to the GPU when a GPU is available.

# %%
def validate(model: nn.Module, val_data: DataLoader) -> LossAcc:
    """
    Returns the loss and accuracy of the model on the validation data.
    """
    # Check for GPU availability and set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Move the model to the specified device
    model.to(device)

    # Set model to evaluation mode
    model.eval()

    # Initialize variables for tracking loss and accuracy
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    # No gradient computation block
    with torch.no_grad():
        # Iterate through validation data
        for data, labels in val_data:
            # Move data and labels to the device
            data, labels = data.to(device), labels.to(device)

            # Forward pass: compute predicted outputs by passing inputs to the model
            outputs = model(data)

            # Calculate batch loss
            loss = F.cross_entropy(outputs, labels)
            total_loss += loss.item()

            # Convert output probabilities to predicted class (get the index of the max probability)
            _, preds = torch.max(outputs, 1)

            # Count correct predictions
            total_correct += (preds == labels).sum().item()
            total_samples += labels.size(0)

    # Calculate average loss and accuracy over all validation data
    average_loss = total_loss / len(val_data)
    accuracy = total_correct / total_samples

    return LossAcc(loss=average_loss, accuracy=accuracy)

# %% [markdown]
# # Training Functions
# Now, to train a model, we have to write training functions. To ease understanding, we've broken the writing of a "training loop" into three functions: `train_batch` to handle a single batch, `train_epoch` to handle a single epoch, and `train_loop` to handle training as many steps as you would like.
#
# Remember, we're still using `nn.functional.cross_entropy` to compute the loss. Don't forget to set the model to `.train()` mode before training!
#
# After setting the model to training, we need to zero out the gradients from the previous step. This is because PyTorch accumulates gradients from each step, and we don't want to accumulate multiple steps of gradients after we've already used their gradients to update the model. We can zero out the gradients by calling the `.zero_grad()` method on the optimizer. Once we've computed the loss, we can call the `.backward()` method on the loss to compute the gradients. Finally, we can call the `.step()` method on the optimizer to update the model weights.
#
# To leverage a GPU for speeding up the computation, you should move the model, data, and labels to the GPU when a GPU is available.

# %%
import torch.nn.functional as F
def train_batch(model: nn.Module, optimizer: optim.Optimizer, inputs: torch.Tensor, labels: torch.Tensor) -> LossAcc:
    """
    Trains the model on a single batch of data.
    Returns the loss and accuracy of the model on the batch.
    """
    # Set model to training mode
    model.train()

    # Zero the gradients
    optimizer.zero_grad()

    # Forward pass: compute predicted outputs by passing inputs to the model
    outputs = model(inputs)

    # Calculate the loss
    loss = F.cross_entropy(outputs, labels)

    # Backpropagate: compute gradient of the loss with respect to model parameters
    loss.backward()

    # Perform a single optimization step (parameter update)
    optimizer.step()

    with torch.no_grad():
        # Calculate the accuracy
        _, preds = torch.max(outputs, 1)
        accuracy = torch.sum(preds == labels).item() / labels.size(0)

    # Return the loss and accuracy
    return LossAcc(loss.item(), accuracy)

def train_epoch(model: nn.Module, optimizer: optim.Optimizer, train_data: DataLoader) -> List[LossAcc]:
    """
    Trains the model on a single epoch of data.
    Returns a list of the loss and accuracy of the model on each batch.
    """
    # Check for GPU availability and set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Move the model to the GPU
    model.to(device)

    batch_loss_accs = []

    # Iterate through training data
    for inputs, labels in train_data:
        inputs, labels = inputs.to(device), labels.to(device)

        loss_acc = train_batch(model, optimizer, inputs, labels)
        batch_loss_accs.append(loss_acc)

    return batch_loss_accs


def train_loop(model: nn.Module, optimizer: optim.Optimizer, train_data: DataLoader, val_data: DataLoader, num_epochs: int = 10) -> TrainValLossAcc:
    """
    Trains the model for a number of epochs and evaluates it on the validation set.
    """
    train_loss_accs = []
    val_loss_accs = []

    best_val_loss = float('inf')
    best_model_state = None

    for epoch in tqdm(range(num_epochs), desc='Training progress...'):
        # Train the model for one epoch
        train_epoch_loss_acc = train_epoch(model, optimizer, train_data)
        train_loss_accs.append(train_epoch_loss_acc)

        # Validate the model
        val_loss_acc = validate(model, val_data)

        # Store validation results
        val_loss_accs.append(val_loss_acc)

        # Check for best model
        if val_loss_acc.loss < best_val_loss:
            best_val_loss = val_loss_acc.loss
            best_model_state = model.state_dict()

    # Load the best model
    if best_model_state:
        model.load_state_dict(best_model_state)

    return TrainValLossAcc(train_loss_accs, val_loss_accs)

# %% [markdown]
# # Train Custom Neural Network
# Finally, we can train your neural network! We'll use basic Stochastic Gradient Descent (SGD) as the optimization routine to train the network. We'll use a learning rate of 0.1, and train for 20 epochs. Feel free to change the optimizer and training epochs.

# %%
# Create optimizer
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Train the model
history: TrainValLossAcc = train_loop(model, optimizer, train_dataloader, val_dataloader, num_epochs)  # CODE HERE
# Out:
# Training progress...:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# We provide this visualization code, to give you a picture of what your model learned while it was training.

# %%
training_history = pd.DataFrame.from_records(
    [loss for batch_losses in history.train for loss in batch_losses],
    columns=LossAcc._fields,
)
training_history["epoch"] = training_history.index / len(train_dataloader)
validation_history = pd.DataFrame.from_records(history.val, columns=LossAcc._fields)
validation_history["epoch"] = validation_history.index + 1

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(training_history["epoch"], training_history["loss"], label="Training")
ax[0].plot(validation_history["epoch"], validation_history["loss"], label="Validation")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].legend()
ax[1].plot(training_history["epoch"], training_history["accuracy"], label="Training")
ax[1].plot(
    validation_history["epoch"], validation_history["accuracy"], label="Validation"
)
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
ax[1].legend()
plt.show()

# %%
# Get the validation accuracy of the best model
# Get the accuracy corresponding to the lowest loss
lowest_loss = validation_history['loss'].min()
best_accuracy = validation_history.loc[validation_history['loss'] == lowest_loss, 'accuracy'].item()
print(f'Best validation accuracy during training: {best_accuracy}')
# Out:
# Best validation accuracy during training: 0.26218097447795824

# %% [markdown]
# # Test Data Prediction: Custom Neural Network Model
# Make Predictions for the Test Data. This function is already defined for you, you just need to call it and pass in the required parameters.

# %%
def generate_test_predictions(model, data_transforms, test_data_dir, output_csv_path, classes):
    # Create a DataLoader for the test dataset
    test_dataset = datasets.ImageFolder(test_data_dir, transform=data_transforms)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    # Load the pre-trained model
    model.eval()

    # Initialize lists to store filenames and predicted class labels
    filenames = []
    predicted_labels = []

    # Iterate through the test dataset and make predictions
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.to('cuda' if torch.cuda.is_available() else 'cpu')
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            # Convert integer labels to class names
            predicted_class_names = [classes[p] for p in predicted]

            # predicted class labels
            predicted_labels.extend(predicted_class_names)


    # Get the basenames of the files
    basenames = [os.path.basename(filename) for filename, _ in test_dataset.imgs]

    # Create a DataFrame to store basenames and predicted labels
    data = {'Basename': basenames, 'Predictions': predicted_labels}
    df = pd.DataFrame(data)

    # Sort the DataFrame by Basename
    df.sort_values(by='Basename', inplace=True)

    # drop the Basename column
    df.drop(columns=['Basename'], inplace=True)

    # Save the sorted predictions to a CSV file
    df.to_csv(output_csv_path, index=False)
    print(f'Predictions saved to {output_csv_path}')

# %%
# Generate test predictions and output the predictions to CSV named 'caltech256_custom_nn_prediction.csv'
generate_test_predictions(
    model = model , # CODE HERE
    data_transforms = data_transforms , # CODE HERE
    test_data_dir = '/content/datasets/CalTech-256/test' , # CODE HERE
    output_csv_path = 'caltech256_custom_nn_prediction.csv' , # CODE HERE
    classes = classes , # CODE HERE
)
# Out:
# Predictions saved to caltech256_custom_nn_prediction.csv

# %% [markdown]
# # Fine-Tune VGG16

# %% [markdown]
# Now, we will be fine-tuning a VGG16 model to perform the same CalTech-256 classification task and compare the performance against the custom model which is trained from scratch.

# %% [markdown]
# # Loading CalTech-256 training data from directory (VGG16)
#
# 1. Define Data Transforms:
#
#   + Define data transformations using `transforms.Compose`. This should include
#     + Padding to make the image a square.
#     + Conversion to a tensor. Converts a PIL Image or numpy.ndarray (H x W x C) in the range `[0, 255]` to a torch.FloatTensor of shape (C x H x W) in the range `[0.0, 1.0]`.
#     + Resizing to (224, 224).
#     + Normalization using the mean and standard deviation values `[0.485, 0.456, 0.406]` and `[0.229, 0.224, 0.225]`. These values are used for the pre-train ImageNet Dataset to set the values to be in the range `[-1, 1]`.
#     + Optionally, you can include other preprocessing steps.
#   + Padding is added to maintain the aspect ratio when resizing to (224, 224). The resizing to (224, 224) and normalization are performed to ensure that the images match the input shape of VGG16 in the later parts.
#
# 2. Load the CalTech-256 Dataset:
#
#   + Set the path to your CalTech-256 `train` dataset directory.
#   + Create the dataset using the `datasets.ImageFolder` class. This class automatically assigns labels based on the subdirectory names.
#
# 3. Get Class Labels:
#
#   + Obtain the class labels (class names) from the `all_dataset.classes` attribute. This will give you a list of class labels in the order they appear in the dataset.

# %%
import torch
from torchvision import transforms, datasets

# Define the data transformations composing of ToTensor and
# - Padding to make the image a square
# - Conversion to a tensor
# - Resize to size (224, 224)
# - Normalization using the mean and standard deviation values
#  `[0.485, 0.456, 0.406]` and `[0.229, 0.224, 0.225]`
# Compose: https://pytorch.org/vision/main/generated/torchvision.transforms.Compose.html
data_transforms =  transforms.Compose([
    SquarePad(),
    transforms.ToTensor(),
    transforms.Resize((224, 224), antialias=True),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])  # CODE HERE

# Create a dataset using ImageFolder
# ImageFolder: https://pytorch.org/vision/main/generated/torchvision.datasets.ImageFolder.html
all_dataset = datasets.ImageFolder(root='/content/datasets/CalTech-256/train', transform=data_transforms)  # CODE HERE

# %% [markdown]
# Split Dataset into training and validation

# %%
# random_split: https://pytorch.org/docs/stable/data.html#torch.utils.data.random_split
total_size = len(all_dataset)
train_size = int(0.8 * total_size)
val_size = total_size - train_size
train_dataset, val_dataset =  random_split(all_dataset, [train_size, val_size])

# %% [markdown]
# Once arranged into a `Dataset`, we wrap the `Dataset` in a `Dataloader` object.

# %%
# DataLoader: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#preparing-your-data-for-training-with-dataloaders
train_dataloader =  DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)  # CODE HERE
val_dataloader =  DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)  # CODE HERE

# %% [markdown]
# # Overview of Fine-Tuning VGG16
#
# VGG16 is a popular deep convolutional neural network architecture used for various computer vision tasks. It consists of two main components: the "features" part and the "classifier" part. Fine-tuning VGG16 involves adjusting these components to adapt the pre-trained model to a new task.
#
# Components of VGG16
# 1. Features Layers:
# The "features" part of VGG16 comprises a stack of convolutional and max-pooling layers. These layers serve as feature extractors and are responsible for capturing hierarchical features from the input image.
# These layers are typically frozen during fine-tuning when using transfer learning. Freezing means that the weights of these layers are not updated during training to preserve the pre-trained knowledge.
# 2. Classifier Layers:
# The "classifier" part of VGG16 consists of fully connected layers (also known as dense layers). These layers are responsible for making predictions based on the extracted features.
# During fine-tuning, the classifier layers are often replaced by a new set of fully connected layers to adapt the model to the specific task.
# ---

# %% [markdown]
# Load the Pre-Trained VGG16 Model:
#
# Begin by loading the pre-trained VGG16 model with weights 'IMAGENET1K_V1', which includes both the features and classifier components. You can do this using PyTorch's torchvision.models.

# %%
import torchvision.models as models

# load VGG16 models with weights 'IMAGENET1K_V1'
model = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)# CODE HERE

# %% [markdown]
# Freeze the Features Layers:
#
# Disable gradient updates to prevent them from changing during training. This step ensures that the model retains its ability to extract relevant features from the data.

# %%
# Get the features part of the model
features =  model.features  # CODE HERE

# Freeze the feature layers
# CODE HERE
for param in features.parameters():
    param.requires_grad = False

# %% [markdown]
# Define and Replace the Classifier:
#
#
# + Replace only the last layer to have 10 output units for the CalTech-256 dataset. Note: Last classifier layer has 4096 input units.
# + Set the last layer to require gradients for fine-tuning.

# %%
# Modify the last layer to have 10 output units for the HAM10000 dataset
# CODE HERE
classifier = model.classifier
classifier[6] = nn.Linear(4096, 10)
# Set the last layer to require gradients for fine-tuning
# CODE HERE
for param in classifier[6].parameters():
    param.requires_grad = True

model.classifier = classifier

# %% [markdown]
# # Fine-Tune VGG16 Model

# %%
# Create optimizer
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Train the model
history: TrainValLossAcc = train_loop(model, optimizer, train_dataloader, val_dataloader, num_epochs)  # CODE HERE
# Out:
# Training progress...:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# We provide this visualization code, to give you a picture of what your model learned while it was training.

# %%
training_history = pd.DataFrame.from_records(
    [loss for batch_losses in history.train for loss in batch_losses],
    columns=LossAcc._fields,
)
training_history["epoch"] = training_history.index / len(train_dataloader)
validation_history = pd.DataFrame.from_records(history.val, columns=LossAcc._fields)
validation_history["epoch"] = validation_history.index + 1

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(training_history["epoch"], training_history["loss"], label="Training")
ax[0].plot(validation_history["epoch"], validation_history["loss"], label="Validation")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].legend()
ax[1].plot(training_history["epoch"], training_history["accuracy"], label="Training")
ax[1].plot(
    validation_history["epoch"], validation_history["accuracy"], label="Validation"
)
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
ax[1].legend()
plt.show()

# %%
# Get the validation accuracy of the best model
# Get the accuracy corresponding to the lowest loss
lowest_loss = validation_history['loss'].min()
best_accuracy = validation_history.loc[validation_history['loss'] == lowest_loss, 'accuracy'].item()
print(f'Best validation accuracy during training: {best_accuracy}')
# Out:
# Best validation accuracy during training: 0.9340277777777778

# %% [markdown]
# # Test Data Prediction: VGG16

# %%
# Generate test predictions and output the predictions to CSV named 'caltech256_custom_nn_prediction.csv'
generate_test_predictions(
    model = model , # CODE HERE
    data_transforms = data_transforms , # CODE HERE
    test_data_dir = '/content/datasets/CalTech-256/test' , # CODE HERE
    output_csv_path = 'caltech256_vgg16_nn_prediction.csv' , # CODE HERE
    classes = classes , # CODE HERE
)
# Out:
# Predictions saved to caltech256_vgg16_nn_prediction.csv
